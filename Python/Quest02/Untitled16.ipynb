# %% [markdown]
# <a href="https://colab.research.google.com/github/phantomer-ai/AIFFEL_quest_cr/blob/main/Python/Quest02/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브에 마운트 하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 파일 절대경로 통해 텍스트 불러오기
file_path = '/content/drive/MyDrive/shakespeare_data/Avengers.txt'

with open(file_path, 'r') as file:
    content = file.read()

# %%
# 소문자로 변환하기
content = content.lower()

#모든 기호 제거하기
refined_text = ""
for character in content:
  if character.isalnum() or character == " ":
    refined_text += character

# 단어 리스트로 분리
words = refined_text.split()

# 확인-> 첫 50 단어 출력하기
print(words[:50])
# Out:
# ['the', 'tesseract', 'has', 'awakenedit', 'is', 'on', 'a', 'neutral', 'world', 'a', 'human', 'worldthey', 'wield', 'its', 'powerbut', 'our', 'ally', 'knows', 'its', 'working', 'so', 'that', 'they', 'never', 'will', 'learnhes', 'ready', 'to', 'lead', 'and', 'our', 'force', 'our', 'chitauri', 'will', 'followthe', 'world', 'will', 'be', 'his', 'and', 'the', 'universe', 'yoursand', 'the', 'humans', 'what', 'can', 'they', 'do']

# %%
# 빈도수 계산
word_frequency = {}

for word in words:
    if word not in word_frequency:
        word_frequency[word] = 1  # 처음 등장하는 단어 =1
    else:
        word_frequency[word] += 1  # 이미 있으면 +=1

# 결과 출력
print(word_frequency)
# Out:
# {'the': 330, 'tesseract': 29, 'has': 18, 'awakenedit': 1, 'is': 114, 'on': 91, 'a': 209, 'neutral': 1, 'world': 18, 'human': 2, 'worldthey': 1, 'wield': 2, 'its': 47, 'powerbut': 1, 'our': 17, 'ally': 1, 'knows': 8, 'working': 6, 'so': 22, 'that': 106, 'they': 29, 'never': 9, 'will': 32, 'learnhes': 1, 'ready': 5, 'to': 214, 'lead': 4, 'and': 73, 'force': 5, 'chitauri': 3, 'followthe': 1, 'be': 62, 'his': 31, 'universe': 2, 'yoursand': 1, 'humans': 4, 'what': 58, 'can': 33, 'do': 40, 'but': 21, 'burnhow': 1, 'bad': 3, 'itthats': 1, 'problem': 2, 'sir': 6, 'we': 82, 'dont': 40, 'knowdr': 1, 'selvig': 7, 'read': 3, 'an': 33, 'energy': 10, 'surge': 1, 'from': 25, 'four': 1, 'hour': 1, 'agonasa': 1, 'didnt': 24, 'authorize': 1, 'pull': 3, 'test': 3, 'phasehe': 1, 'wasnt': 3, 'testing': 1, 'it': 81, 'he': 57, 'even': 6, 'in': 89, 'room': 3, 'spontaneous': 1, 'advancementit': 1, 'just': 27, 'turned': 1, 'itself': 3, 'onwhat': 1, 'are': 51, 'engine': 8, 'levels': 2, 'nowclimbing': 1, 'when': 10, 'couldnt': 3, 'shut': 8, 'down': 16, 'ordered': 1, 'evachow': 1, 'long': 8, 'get': 41, 'everyone': 3, 'outcampus': 1, 'should': 20, 'clear': 2, 'next': 6, 'half': 2, 'hourdo': 1, 'bettersir': 1, 'evacuation': 1, 'maybe': 4, 'futilewe': 1, 'tell': 16, 'them': 25, 'go': 12, 'back': 17, 'sleepif': 1, 'cant': 19, 'control': 5, 'tesseracts': 2, 'energythere': 1, 'may': 8, 'not': 81, 'minimum': 1, 'safe': 2, 'distancei': 1, 'need': 39, 'you': 265, 'make': 10, 'sure': 6, 'phasesir': 1, 'really': 11, 'priority': 1, 'right': 18, 'nowuntil': 1, 'such': 1, 'time': 12, 'as': 22, 'endswe': 1, 'act': 2, 'though': 5, 'intends': 1, 'spin': 1, 'onclear': 1, 'out': 44, 'tech': 1, 'below': 1, 'every': 10, 'piece': 1, 'of': 119, 'phase': 4, '2': 4, 'truck': 1, 'goneyes': 1, 'come': 27, 'with': 31, 'metalk': 1, 'me': 49, 'doctor': 9, 'director': 4, 'there': 21, 'anything': 10, 'know': 52, 'for': 69, 'certain': 2, 'misbehaving': 1, 'supposed': 3, 'funnyno': 1, 'funny': 2, 'at': 15, 'allthe': 1, 'only': 13, 'active': 1, 'shesmisbehavinghow': 1, 'soon': 3, 'until': 7, 'plugshes': 1, 'sourceif': 1, 'turn': 6, 'off': 15, 'power': 11, 'she': 3, 'turns': 1, 'if': 28, 'reaches': 1, 'peak': 1, 'level': 2, 'weve': 2, 'prepared': 2, 'this': 66, 'harnessing': 1, 'space': 5, 'have': 62, 'harnessour': 1, 'calculations': 1, 'far': 5, 'completenow': 1, 'shes': 1, 'throwing': 1, 'interference': 1, 'radiationnothing': 1, 'harmful': 1, 'low': 2, 'gamma': 5, 'radiationthat': 1, 'harmfulwheres': 1, 'agent': 10, 'bartonthe': 1, 'hawk': 1, 'up': 34, 'nest': 1, 'usualagent': 1, 'barton': 9, 'report': 1, 'mei': 3, 'gave': 2, 'detail': 1, 'couldkeep': 1, 'close': 6, 'eye': 2, 'things': 7, 'i': 150, 'see': 11, 'better': 6, 'distance': 1, 'seeing': 4, 'might': 8, 'set': 2, 'thing': 10, 'spiking': 1, 'againno': 1, 'one': 17, 'or': 8, 'goneits': 1, 'oven': 1, 'cleanno': 1, 'contacts': 1, 'no': 39, 'imsif': 1, 'was': 46, 'any': 8, 'tampering': 1, 'end': 9, 'cube': 11, 'dooryeah': 1, 'doorway': 1, 'other': 12, 'doors': 1, 'open': 5, 'both': 1, 'sidessir': 1, 'please': 3, 'put': 20, 'spearyou': 1, 'heartplease': 1, 'still': 9, 'doesnt': 6, 'messierof': 1, 'course': 3, 'does': 10, 'ive': 12, 'too': 10, 'elsei': 1, 'am': 10, 'loki': 20, 'asgard': 8, 'burdened': 1, 'glorious': 3, 'purpose': 1, 'brother': 2, 'thorwe': 1, 'quarrel': 2, 'your': 41, 'peoplean': 1, 'ant': 1, 'boot': 1, 'planning': 2, 'step': 3, 'us': 19, 'glad': 2, 'tidings': 1, 'made': 13, 'free': 3, 'whatfreedom': 1, 'freedom': 2, 'lifes': 2, 'great': 3, 'lieonce': 1, 'accept': 1, 'heartyou': 1, 'peaceyeah': 1, 'say': 11, 'peace': 3, 'kind': 7, 'ofthink': 1, 'mean': 13, 'piecesir': 1, 'fury': 14, 'stallingthis': 1, 'place': 4, 'about': 30, 'blowdrop': 1, 'hundred': 3, 'feet': 2, 'raw': 2, 'materialhe': 1, 'means': 5, 'bury': 1, 'like': 37, 'pharaohs': 1, 'odin': 1, 'righthes': 1, 'portal': 8, 'collapsing': 1, 'itselfyou': 1, 'got': 37, 'two': 4, 'minutes': 2, 'before': 6, 'goes': 2, 'criticaldrop': 1, 'himneed': 1, 'these': 8, 'vehicl ...

# %%
# 빈도수 기준으로 내림차순 정렬
sorted_words = sorted(word_frequency.items(), key=lambda x: x[1], reverse=True)

# 정렬된 순서대로 인덱스 부여
frequency_indexed_word = {}
for index, (word, freq) in enumerate(sorted_words, start=1):
    frequency_indexed_word[word] = {'index': index, 'frequency': freq}

# 최종 결과 출력
print("정렬 및 인덱스 부여 결과:", frequency_indexed_word)
# Out:
# 정렬 및 인덱스 부여 결과: {'the': {'index': 1, 'frequency': 330}, 'you': {'index': 2, 'frequency': 265}, 'to': {'index': 3, 'frequency': 214}, 'a': {'index': 4, 'frequency': 209}, 'i': {'index': 5, 'frequency': 150}, 'of': {'index': 6, 'frequency': 119}, 'is': {'index': 7, 'frequency': 114}, 'that': {'index': 8, 'frequency': 106}, 'on': {'index': 9, 'frequency': 91}, 'in': {'index': 10, 'frequency': 89}, 'we': {'index': 11, 'frequency': 82}, 'it': {'index': 12, 'frequency': 81}, 'not': {'index': 13, 'frequency': 81}, 'and': {'index': 14, 'frequency': 73}, 'for': {'index': 15, 'frequency': 69}, 'this': {'index': 16, 'frequency': 66}, 'be': {'index': 17, 'frequency': 62}, 'have': {'index': 18, 'frequency': 62}, 'what': {'index': 19, 'frequency': 58}, 'he': {'index': 20, 'frequency': 57}, 'know': {'index': 21, 'frequency': 52}, 'are': {'index': 22, 'frequency': 51}, 'me': {'index': 23, 'frequency': 49}, 'its': {'index': 24, 'frequency': 47}, 'was': {'index': 25, 'frequency': 46}, 'out': {'index': 26, 'frequency': 44}, 'get': {'index': 27, 'frequency': 41}, 'your': {'index': 28, 'frequency': 41}, 'do': {'index': 29, 'frequency': 40}, 'dont': {'index': 30, 'frequency': 40}, 'need': {'index': 31, 'frequency': 39}, 'no': {'index': 32, 'frequency': 39}, 'my': {'index': 33, 'frequency': 39}, 'like': {'index': 34, 'frequency': 37}, 'got': {'index': 35, 'frequency': 37}, 'im': {'index': 36, 'frequency': 36}, 'all': {'index': 37, 'frequency': 35}, 'up': {'index': 38, 'frequency': 34}, 'can': {'index': 39, 'frequency': 33}, 'an': {'index': 40, 'frequency': 33}, 'will': {'index': 41, 'frequency': 32}, 'his': {'index': 42, 'frequency': 31}, 'with': {'index': 43, 'frequency': 31}, 'did': {'index': 44, 'frequency': 31}, 'gonna': {'index': 45, 'frequency': 31}, 'about': {'index': 46, 'frequency': 30}, 'were': {'index': 47, 'frequency': 30}, 'tesseract': {'index': 48, 'frequency': 29}, 'they': {'index': 49, 'frequency': 29}, 'if': {'index': 50, 'frequency': 28}, 'think': {'index': 51, 'frequency': 28}, 'just': {'index': 52, 'frequency': 27}, 'come': {'index': 53, 'frequency': 27}, 'here': {'index': 54, 'frequency': 27}, 'from': {'index': 55, 'frequency': 25}, 'them': {'index': 56, 'frequency': 25}, 'didnt': {'index': 57, 'frequency': 24}, 'him': {'index': 58, 'frequency': 24}, 'how': {'index': 59, 'frequency': 23}, 'stark': {'index': 60, 'frequency': 23}, 'well': {'index': 61, 'frequency': 23}, 'youre': {'index': 62, 'frequency': 23}, 'so': {'index': 63, 'frequency': 22}, 'as': {'index': 64, 'frequency': 22}, 'hes': {'index': 65, 'frequency': 22}, 'but': {'index': 66, 'frequency': 21}, 'there': {'index': 67, 'frequency': 21}, 'should': {'index': 68, 'frequency': 20}, 'put': {'index': 69, 'frequency': 20}, 'loki': {'index': 70, 'frequency': 20}, 'cant': {'index': 71, 'frequency': 19}, 'us': {'index': 72, 'frequency': 19}, 'has': {'index': 73, 'frequency': 18}, 'world': {'index': 74, 'frequency': 18}, 'right': {'index': 75, 'frequency': 18}, 'thats': {'index': 76, 'frequency': 18}, 'why': {'index': 77, 'frequency': 18}, 'our': {'index': 78, 'frequency': 17}, 'back': {'index': 79, 'frequency': 17}, 'one': {'index': 80, 'frequency': 17}, 'down': {'index': 81, 'frequency': 16}, 'tell': {'index': 82, 'frequency': 16}, 'now': {'index': 83, 'frequency': 16}, 'at': {'index': 84, 'frequency': 15}, 'off': {'index': 85, 'frequency': 15}, 'take': {'index': 86, 'frequency': 15}, 'fury': {'index': 87, 'frequency': 14}, 'man': {'index': 88, 'frequency': 14}, 'only': {'index': 89, 'frequency': 13}, 'made': {'index': 90, 'frequency': 13}, 'mean': {'index': 91, 'frequency': 13}, 'want': {'index': 92, 'frequency': 13}, 'isnt': {'index': 93, 'frequency': 13}, 'wanna': {'index': 94, 'frequency': 13}, 'way': {'index': 95, 'frequency': 13}, 'people': {'index': 96, 'frequency': 13}, 'would': {'index': 97, 'frequency': 13}, 'go': {'index': 98, 'frequency': 12}, 'time': {'index': 99, 'frequency': 12}, 'other': {'index': 100, 'frequency': 12}, 'ive': {'index': 101, 'frequency': 12}, ...

# %%
# 텍스트를 인덱스 리스트로 변환하는 함수
def text_to_index(frequency_indexed_word):
    input_text = input("텍스트를 입력하세요: ")

    # 1. 입력 텍스트를 소문자로 변환
    content = input_text.lower()

    # 2. 기호 제거
    refined_text = ""
    for character in content:
        if character.isalnum() or character == " ":
            refined_text += character

    # 3. 단어를 리스트로 분리
    words = refined_text.split()

    # 4. 단어를 인덱스로 변환
    index_list = []
    for word in words:
        if word in frequency_indexed_word:
            index_list.append(frequency_indexed_word[word]['index'])
        else:
            index_list.append(-1)  # 없는 단어는 -1로 표시

    # 결과 반환
    return index_list

# 함수 호출
result = text_to_index(frequency_indexed_word)
print("인덱스 변환 결과:", result)
# Out:
# 텍스트를 입력하세요: the
# 인덱스 변환 결과: [1]
